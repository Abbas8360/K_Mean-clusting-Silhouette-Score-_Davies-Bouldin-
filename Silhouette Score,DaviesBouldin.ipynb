# %% [markdown]
# DAY 2
#
# Problem Statement:
# Online Retail Customer Segmentation using K-Means Clustering
# You are provided with a dataset containing information about customers of an *online*
# retail store. The dataset includes features such as:
# • Customer ID
# • Age
# • Annual Income (k$)
# • Spending Score (1-100): A score assigned by the store based on customer
# behavior and spending habits.
# • Gender (optional)**bold text** **bold text**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pandas as pd
data = pd.read_csv('Mall_Customers.csv')
features = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
kmeans = KMeans(n_clusters=3, random_state=42)
data['Cluster'] = kmeans.fit_predict(scaled_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

# Silhouette Score
silhouette_avg = silhouette_score(scaled_features, data['Cluster'])
print(f'Silhouette Score: {silhouette_avg}')

# Davies-Bouldin Index
db_index = davies_bouldin_score(scaled_features, data['Cluster'])
print(f'Davies-Bouldin Index: {db_index}')
# Out:
# Silhouette Score: 0.357793388710272
# Davies-Bouldin Index: 1.050270139649266

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 2D Plot
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', data=data, palette='viridis')
plt.title('Customer Segments')
plt.show()

# %% [markdown]
# ![abc.png](data:image/png;base64,...)
